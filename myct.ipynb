# %%
# CTranslate2

# %%
# !pip install ctranslate2==2.24.0 OpenNMT-py==2.* sentencepiece
# !apt-get install libomp5
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.6/226.6 kB 14.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 27.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 43.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 31.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 14.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.9 MB/s eta 0:00:00
# ...

# %%
# !unzip /content/myct.zip
# !rm /content/myct.zip
# Out:
# Archive:  /content/myct.zip
#    creating: myct/
#    creating: myct/bin/
#   inflating: myct/bin/ct2-translator
#   inflating: myct/CMakeLists.txt
#    creating: myct/include/
#    creating: myct/include/ctranslate2/
#   inflating: myct/include/ctranslate2/allocator.h
#   inflating: myct/include/ctranslate2/batch_reader.h
#   inflating: myct/include/ctranslate2/bfloat16.h
#   inflating: myct/include/ctranslate2/buffered_translation_wrapper.h
#   inflating: myct/include/ctranslate2/decoding.h
#   inflating: myct/include/ctranslate2/decoding_utils.h
#   inflating: myct/include/ctranslate2/devices.h
#   inflating: myct/include/ctranslate2/encoder.h
#   inflating: myct/include/ctranslate2/encoding.h
#   inflating: myct/include/ctranslate2/filesystem.h
#   inflating: myct/include/ctranslate2/generation.h
#   inflating: myct/include/ctranslate2/generator.h
#    creating: myct/include/ctranslate2/layers/
#   inflating: myct/include/ctranslate2/layers/attention.h
# ...

# %%
# %cd /content
# 可以进行量化，使用 --quantization 参数控制，可选（float16、int16、int8_float16、int8）
# 也可以对自己微调好的模型进行量化
# !ct2-transformers-converter --model Helsinki-NLP/opus-mt-zh-en --output_dir opus-mt-zh-en --quantization int8

# %cd /content/opus-mt-zh-en
# !wget https://huggingface.co/Helsinki-NLP/opus-mt-zh-en/resolve/main/source.spm  https://huggingface.co/Helsinki-NLP/opus-mt-zh-en/resolve/main/target.spm
# Out:
# /content
# /usr/local/lib/python3.11/dist-packages/numpy/_core/getlimits.py:552: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /usr/local/lib/python3.11/dist-packages/numpy/_core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /usr/local/lib/python3.11/dist-packages/numpy/_core/getlimits.py:552: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /usr/local/lib/python3.11/dist-packages/numpy/_core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# ...

# %%
# 编译sentencepiece的库文件，也就是libsentencepiece.a

# %%
# %cd /content

# !git clone https://github.com/google/sentencepiece.git
# %cd sentencepiece
# !mkdir build
# %cd build
# !cmake .. -DCMAKE_BUILD_TYPE=Release
# !make -j$(nproc)

# %%
# %cd /content/myct
# !mkdir build
# %cd build
# !cmake ..
# !make
# !./main "你好，你是谁？你在干深，啥都干十多个人、四uUI防护认识复苏" "checkpoint"
# Out:
# /content/myct
# mkdir: cannot create directory ‘build’: File exists
# /content/myct/build
# CMake Deprecation Warning at CMakeLists.txt:1 (cmake_minimum_required):
#   Compatibility with CMake < 3.10 will be removed from a future version of
#   CMake.
#
#   Update the VERSION argument <min> value.  Or, use the <min>...<max> syntax
#   to tell CMake that the project requires at least <min> but has been updated
#   to work with policies introduced by <max> or earlier.
#
#
# -- Configuring done (0.0s)
# -- Generating done (0.0s)
# -- Build files have been written to: /content/myct/build
# [ 50%] Building CXX object CMakeFiles/main.dir/main.cpp.o
# [100%] Linking CXX executable main
# [100%] Built target main
# Tokenized input: >>eng<< ▁你好 , 你 是谁 ? 你在 干 深 , 啥 都 干 十 多 个人 、 四 u U I 防护 认识 复苏
# ...

# %%
import time

time1 = time.time()
# %cd /content/myct/build
# !./main "我们计算尾随静默的持续时间。如果它大于用户指定的值，则激活。" "opus-mt-zh-en-int8"
